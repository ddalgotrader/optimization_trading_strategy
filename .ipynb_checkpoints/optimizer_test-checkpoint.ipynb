# %%
from StrategyOptimizer import StrategyOptimizer as optimizer
from Metrics import *
from Strategies import *

# %%
data_test=pd.read_csv('oanda_EURUSD_1_year.csv', parse_dates=['Date'], index_col='Date')

# %%
optimizer=optimizer(folds=3, test_size=0.3,symbol='EUR_USD',
                    data_tester=data_test, strategy_func=rsi)
# Out:
# /home/slawomir/Portfolio/blog_articles/Optimization_of_trading_strategy/optimization_trading_strategy/StrategyOptimizer.py:38: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.buy_and_hold=pd.Series()

# %%
optimizer.test_params(freq=[30,45,60], window=(20,30,1), down_level=(25,30,1),
                      up_level=(65,70,1), neutral_level_dist=[0], bars_ob=(1,4,1))
# Out:
# 100%|███████████████████████████████████████| 2250/2250 [02:48<00:00, 13.36it/s]

# %%
optimizer.results_overview
# Out:
#       freq  window  down_level  up_level  neutral_level_dist  bars_ob  \
# 0       30      20          25        65                   0        1
# 1       30      20          25        65                   0        2
# 2       30      20          25        65                   0        3
# 3       30      20          25        66                   0        1
# 4       30      20          25        66                   0        2
# ...    ...     ...         ...       ...                 ...      ...
# 2245    60      29          29        68                   0        2
# 2246    60      29          29        68                   0        3
# 2247    60      29          29        69                   0        1
# 2248    60      29          29        69                   0        2
# 2249    60      29          29        69                   0        3
#
#       simple_return  mean_return    stddev  sharpe_ratio  sortino_ratio  \
# ...

# %%
optimizer.forward_test()
# Out:
# 100%|███████████████████████████████████████| 2250/2250 [02:06<00:00, 17.73it/s]

# %%
optimizer.forward_results_overview
# Out:
#       freq  window  down_level  up_level  neutral_level_dist  bars_ob  \
# 0       30      20          25        65                   0        1
# 1       30      20          25        65                   0        2
# 2       30      20          25        65                   0        3
# 3       30      20          25        66                   0        1
# 4       30      20          25        66                   0        2
# ...    ...     ...         ...       ...                 ...      ...
# 2245    60      29          29        68                   0        2
# 2246    60      29          29        68                   0        3
# 2247    60      29          29        69                   0        1
# 2248    60      29          29        69                   0        2
# 2249    60      29          29        69                   0        3
#
#       simple_return  mean_return    stddev  sharpe_ratio  sortino_ratio  \
# ...

# %%
optimizer.find_best_strategies(metric='sharpe_ratio', sort_arg='test_metric')
# Out:
# /home/slawomir/Portfolio/blog_articles/Optimization_of_trading_strategy/optimization_trading_strategy/StrategyOptimizer.py:259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_better_than_benchmark['distance']=abs(df_better_than_benchmark[f'{metric}_train']-df_better_than_benchmark[f'{metric}_test'])
#       sharpe_ratio_test  sharpe_ratio_train  distance  freq  window  \
# 2098           0.374830            1.042900  0.668070    60      27
# 2097           0.374830            1.121507  0.746677    60      27
# 1838           0.368603            0.662400  0.293797    60      24
# 2095           0.361983            0.740977  0.378993    60      27
# 2241           0.358843            1.568477  1.209633    60      29
# ...
